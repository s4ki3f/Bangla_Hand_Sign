# %% [markdown]
# <a href="https://colab.research.google.com/github/s4ki3f/Bangla_Hand_Sign/blob/main/Hand_SIgn_YOLOv8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
/content/drive/MyDrive/Dataset/BdSL-D1500

# %%
import os
import shutil
from sklearn.model_selection import train_test_split

# Set the paths for your source dataset folder and destination folders
source_folder = '/content/drive/MyDrive/Dataset/BdSL-D1500/BdSL-D1500'
train_folder = '/content/drive/MyDrive/Dataset/BdSL-D1500/BdSL-D1500/train'
test_folder = '/content/drive/MyDrive/Dataset/BdSL-D1500/BdSL-D1500/test'
val_folder = '/content/drive/MyDrive/Dataset/BdSL-D1500/BdSL-D1500/validation'

# List all the files in the source folder
file_list = os.listdir(source_folder)

# Split the dataset into train, test, and validation sets
train_files, test_val_files = train_test_split(file_list, test_size=0.3, random_state=42)
test_files, val_files = train_test_split(test_val_files, test_size=0.33, random_state=42)

# Create destination folders if they don't exist
os.makedirs(train_folder, exist_ok=True)
os.makedirs(test_folder, exist_ok=True)
os.makedirs(val_folder, exist_ok=True)

# Move files to respective folders
for file in train_files:
    shutil.move(os.path.join(source_folder, file), os.path.join(train_folder, file))

for file in test_files:
    shutil.move(os.path.join(source_folder, file), os.path.join(test_folder, file))

for file in val_files:
    shutil.move(os.path.join(source_folder, file), os.path.join(val_folder, file))

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-d5df0069828e> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#     101 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#     102   """Mount your Google Drive at the specified mountpoint path."""
# --> 103   return _mount(
#     104       mountpoint,
#     105       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     130   )
#     131   if ephemeral:
# --> 132     _message.blocking_request(
#     133         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None
# ...

# %%
# %cd /content/drive/MyDrive/Dataset/BdSL-D1500/DL
# Out:
# /content/drive/MyDrive/Dataset/BdSL-D1500/DL

# %%
# !ls BdSL-D1500/BdSL-D1500
# Out:
# 0    1	4  7  Counting	  S12_go_CC   S15_co_CC   S18_jho_CC  S20_To_CC
# 00   2	5  8  S10_ko_CC   S13_gho_CC  S16_Cho_CC  S19_Io_CC
# 000  3	6  9  S11_Kho_CC  S14_Umo_CC  S17_jo_CC   S1_o_CC

# %%
# !unzip /content/drive/MyDrive/Dataset/archive.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: BdSL-D1500/BdSL-D1500/Sign 6_I/Sign 6_I_New_725.jpg
#   inflating: BdSL-D1500/BdSL-D1500/Sign 6_I/Sign 6_I_New_726.jpg
#   inflating: BdSL-D1500/BdSL-D1500/Sign 6_I/Sign 6_I_New_727.jpg
#   inflating: BdSL-D1500/BdSL-D1500/Sign 6_I/Sign 6_I_New_728.jpg
#   inflating: BdSL-D1500/BdSL-D1500/Sign 6_I/Sign 6_I_New_729.jpg
#   inflating: BdSL-D1500/BdSL-D1500/Sign 6_I/Sign 6_I_New_73.jpg
#   inflating: BdSL-D1500/BdSL-D1500/Sign 6_I/Sign 6_I_New_730.jpg
#   inflating: BdSL-D1500/BdSL-D1500/Sign 6_I/Sign 6_I_New_731.jpg
#   inflating: BdSL-D1500/BdSL-D1500/Sign 6_I/Sign 6_I_New_732.jpg
#   inflating: BdSL-D1500/BdSL-D1500/Sign 6_I/Sign 6_I_New_733.jpg
#   inflating: BdSL-D1500/BdSL-D1500/Sign 6_I/Sign 6_I_New_734.jpg
#   inflating: BdSL-D1500/BdSL-D1500/Sign 6_I/Sign 6_I_New_735.jpg
#   inflating: BdSL-D1500/BdSL-D1500/Sign 6_I/Sign 6_I_New_736.jpg
#   inflating: BdSL-D1500/BdSL-D1500/Sign 6_I/Sign 6_I_New_737.jpg
# ...

# %%
# !pip install split-folders

# %%
import splitfolders

# %%
input_file = '/content/drive/MyDrive/Dataset/BdSL-D1500/DL/BdSL-D1500/BdSL-D1500'
output_file = '/content/drive/MyDrive/Dataset/BdSL-D1500/DLsplited'

# %%
splitfolders.ratio(input_file, output=output_file, seed=38, ratio=(.7, .2, .1), group_prefix=None)
# Out:
# Copying files: 132061 files [23:21, 94.22 files/s]

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.164 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 34.5/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !yolo task=classify mode=train model=yolov8n-cls.pt data='/content/drive/MyDrive/Dataset/BdSL-D1500/DLsplited' epochs=3b
# Out:
# ...
# 100% 5.28M/5.28M [00:00<00:00, 84.7MB/s]
# Ultralytics YOLOv8.0.164 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=classify mode=val model=/content/drive/MyDrive/Dataset/BdSL-D1500/DL/runs/classify/train/weights/best.pt data='/content/drive/MyDrive/Dataset/BdSL-D1500/DLsplited'
# Out:
# Ultralytics YOLOv8.0.164 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-cls summary (fused): 73 layers, 1546327 parameters, 0 gradients
# train: /content/drive/MyDrive/Dataset/BdSL-D1500/DLsplited/train... found 92439 images in 87 classes ✅
# val: /content/drive/MyDrive/Dataset/BdSL-D1500/DLsplited/val... found 26409 images in 87 classes ✅
# test: /content/drive/MyDrive/Dataset/BdSL-D1500/DLsplited/test... found 13213 images in 87 classes ✅
# val: Scanning /content/drive/MyDrive/Dataset/BdSL-D1500/DLsplited/val... 26409 images, 0 corrupt: 100% 26409/26409 [00:00<?, ?it/s]
#                classes   top1_acc   top5_acc: 100% 1651/1651 [02:08<00:00, 12.80it/s]
#                    all          1          1
# Speed: 0.1ms preprocess, 0.6ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to runs/classify/val

# %%
# !yolo task=classify mode=predict model='/content/drive/MyDrive/Dataset/BdSL-D1500/DL/runs/classify/train/weights/best.pt' conf=0.25 source='https://www.youtube.com/watch?v=WUipEV570DI'
# Out:
# Ultralytics YOLOv8.0.164 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-cls summary (fused): 73 layers, 1546327 parameters, 0 gradients
#
# requirements: Ultralytics requirement ['yt-dlp'] not found, attempting AutoUpdate...
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 15.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 85.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 33.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 277.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 47.5 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 8.4s, installed 1 package: ['yt-dlp']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# 1/1: https://www.youtube.com/watch?v=WUipEV570DI... Success ✅ (9719 frames of shape 1920x1080 at 25.00 FPS)
#
# ...

# %%
# !yolo task=classify mode=predict model='/content/drive/MyDrive/Dataset/BdSL-D1500/DL/runs/classify/train/weights/best.pt' conf=0.25 source='/content/drive/MyDrive/Dataset/BdSL-D1500/DLsplited/test/1/1_New_1008.jpg'
# Out:
# Ultralytics YOLOv8.0.164 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-cls summary (fused): 73 layers, 1546327 parameters, 0 gradients
#
# image 1/1 /content/drive/MyDrive/Dataset/BdSL-D1500/DLsplited/test/1/1_New_1008.jpg: 224x224 1 1.00, Sign 34_RHo 0.00, 2 0.00, S33_lo_CC 0.00, S26_tho_CC 0.00, 4.1ms
# Speed: 1.9ms preprocess, 4.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/classify/predict2

# %%
# !yolo task=classify mode=predict model='/content/drive/MyDrive/Dataset/BdSL-D1500/DL/runs/classify/train/weights/best.pt' conf=0.25 source='/content/drive/MyDrive/Dataset/BdSL-D1500/DLsplited/test/S38_Chandrabindu_CC/S38_Chandrabindu_CC_New_1008.jpg'
# Out:
# Ultralytics YOLOv8.0.164 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-cls summary (fused): 73 layers, 1546327 parameters, 0 gradients
#
# image 1/1 /content/drive/MyDrive/Dataset/BdSL-D1500/DLsplited/test/S38_Chandrabindu_CC/S38_Chandrabindu_CC_New_1008.jpg: 224x224 S38_Chandrabindu_CC 1.00, S21_THo_CC 0.00, S26_tho_CC 0.00, S22_Do_CC 0.00, S5_ro_CC 0.00, 4.1ms
# Speed: 1.7ms preprocess, 4.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/classify/predict3

# %%
# !yolo task=classify mode=predict model='/content/drive/MyDrive/Dataset/BdSL-D1500/DL/runs/classify/train/weights/best.pt' conf=0.25 source='/content/drive/MyDrive/Dataset/BdSL-D1500/DLsplited/test/Sign 33_RO/Sign 33_RO_New_1078.jpg'
# Out:
# Ultralytics YOLOv8.0.164 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-cls summary (fused): 73 layers, 1546327 parameters, 0 gradients
#
# image 1/1 /content/drive/MyDrive/Dataset/BdSL-D1500/DLsplited/test/Sign 33_RO/Sign 33_RO_New_1078.jpg: 224x224 Sign 33_RO 1.00, S27_do_CC 0.00, Sign 34_RHo 0.00, Sign 13_jo 0.00, Sign 12_cho 0.00, 3.9ms
# Speed: 1.6ms preprocess, 3.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/classify/predict4
